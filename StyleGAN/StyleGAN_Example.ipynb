# %%
######### style-transfer-pytorch
# https://github.com/crowsonkb/style-transfer-pytorch

# %%
# !git clone https://github.com/crowsonkb/style-transfer-pytorch
# !pip install -e ./style-transfer-pytorch

# !curl -OL 'https://raw.githubusercontent.com/jcjohnson/neural-style/master/examples/inputs/golden_gate.jpg'
# !curl -OL 'https://raw.githubusercontent.com/jcjohnson/neural-style/master/examples/inputs/starry_night.jpg'

from IPython.display import clear_output 
clear_output()

# %%
import time
start_time = time.time()
# !style_transfer golden_gate.jpg starry_night.jpg -s 128+
end_time = time.time()
# clear_output()
print('학습 완료')
print(end_time - start_time)
# Out:
# Traceback (most recent call last):
#   File "/usr/local/bin/style_transfer", line 33, in <module>
#     sys.exit(load_entry_point('style-transfer-pytorch', 'console_scripts', 'style_transfer')())
# TypeError: main() missing 3 required positional arguments: 'content', 'styles', and 'end_scale'
# 학습 완료
# 5.444241046905518

# %%
import IPython

IPython.display.Image('out.png', width=256)

# %%
######### fast_neural_style
# https://github.com/pytorch/examples/tree/main/fast_neural_style

# %%
# !git clone https://github.com/pytorch/examples.git

# %cd examples/fast_neural_style

# model download => A 입력
# !python download_saved_models.py
# !unzip saved_models.zip
# Out:
# Cloning into 'examples'...
# remote: Enumerating objects: 3417, done.
# remote: Counting objects: 100% (9/9), done.
# remote: Compressing objects: 100% (8/8), done.
# remote: Total 3417 (delta 1), reused 2 (delta 1), pack-reused 3408
# Receiving objects: 100% (3417/3417), 40.34 MiB | 23.10 MiB/s, done.
# Resolving deltas: 100% (1680/1680), done.
# /content/examples/fast_neural_style/examples/fast_neural_style
# 100% 23.9M/23.9M [00:00<00:00, 29.9MB/s]
# Archive:  saved_models.zip
# replace saved_models/candy.pth? [y]es, [n]o, [A]ll, [N]one, [r]ename: A
#   inflating: saved_models/candy.pth
#   inflating: saved_models/mosaic.pth
#   inflating: saved_models/rain_princess.pth
#   inflating: saved_models/udnie.pth

# %%
# !python neural_style/neural_style.py eval \
--content-image images/content-images/amber.jpg \
--model saved_models/candy.pth \
--output-image outputs/k.png \
--cuda 1

# %%
# !python neural_style/neural_style.py train \
--style-image images/content-images/amber.jpg \
--save-model-dir </path/to/save-model/folder>\
--epochs 2 --cuda 1

# %%
import IPython

IPython.display.Image('outputs/k.png', width=300)

# %%
######### fast_neural_style
# https://github.com/pytorch/examples/tree/main/fast_neural_style
